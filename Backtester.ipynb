# %%
from large_eval_framework import runner 
from large_eval_framework import data_loader as dl
from large_eval_framework import visualization as vis

# %%
loader = dl.DataLoader()
symbols = loader.get_all_symbols()
loader.filter_good_tickers(symbols)
# Out:
# Found 6995 symbols
# ...
# Screening tickers:   2%|▍                    | 165/6995 [00:30<17:21,  6.56it/s]HPAIW: Period 'max' is invalid, must be one of: 1d, 5d
# RDAGW: Period 'max' is invalid, must be one of: 1d, 5d
# ...
# Screening tickers:   3%|▋                    | 242/6995 [00:45<22:33,  4.99it/s]Failed to get ticker 'CRD/A' reason: Expecting value: line 1 column 1 (char 0)
# $CRD/A: possibly delisted; no timezone found
# ...
# Screening tickers:   4%|▊                    | 281/6995 [00:52<29:44,  3.76it/s]ATMCW: Period 'max' is invalid, must be one of: 1d, 5d
# $LXP^C: possibly delisted; no timezone found
# ...
# Screening tickers:   4%|▉                    | 293/6995 [00:54<24:33,  4.55it/s]Failed to get ticker 'AKO/A' reason: Expecting value: line 1 column 1 (char 0)
# $AKO/A: possibly delisted; no timezone found
# ...
# Screening tickers:   6%|█▎                   | 434/6995 [01:19<18:55,  5.78it/s]NXPLW: Period 'max' is invalid, must be one of: 1d, 5d
# $ATH^E: possibly delisted; no timezone found
# ...

# %%
runner.run_strategy_on_tickers()
